# %% [markdown]
# ## Indexing, Selecting & Assigning
#
# ### Introduction
#
# Selecting specific values of a pandas DataFrame or Series to work on is an implicit step in almost any data operation you'll run, so one of the first things you need to learn in working with data in Python is how to go about selecting the data points relevant to you quickly and effectively.

# %% [markdown]
# ### Native accessors
# Native Python objects provide good ways of indexing data. Pandas carries all of these over, which helps make it easy to start with.
#
# Consider this csv file: `https://raw.githubusercontent.com/ahm90-dev/pandas_activity/refs/heads/main/csv/annual-enterprise-survey-2023-financial-year-provisional.csv`

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ahm90-dev/pandas_activity/refs/heads/main/csv/annual-enterprise-survey-2023-financial-year-provisional.csv"
data = pd.read_csv(url)

data
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# 3                  All industries  Dollars (millions)           H07
# 4                  All industries  Dollars (millions)           H08
# ...                           ...                 ...           ...
# 50980  Food product manufacturing          Percentage           H37
# 50981  Food product manufacturing          Percentage           H38
# 50982  Food product manufacturing          Percentage           H39
# 50983  Food product manufacturing          Percentage           H40
# 50984  Food product manufacturing          Percentage           H41
#
#                                          Variable_name      Variable_category  \
# 0                                         Total income  Financial performance
# 1      Sales, government funding, grants and subsidies  Financial performance
# 2                    Interest, dividends and donations  Financial performance
# 3                                 Non-operating income  Financial performance
# 4                                    Total expenditure  Financial performance
# ...                                                ...                    ...
# 50980                                      Quick ratio       Financial ratios
# 50981              Margin on sales of goods for resale       Financial ratios
# 50982                                 Return on equity       Financial ratios
# 50983                           Return on total assets       Financial ratios
# 50984                            Liabilities structure       Financial ratios
#
#         Value                             Industry_code_ANZSIC06
# 0      930995  ANZSIC06 divisions A-S (excluding classes K633...
# 1      821630  ANZSIC06 divisions A-S (excluding classes K633...
# 2       84354  ANZSIC06 divisions A-S (excluding classes K633...
# 3       25010  ANZSIC06 divisions A-S (excluding classes K633...
# 4      832964  ANZSIC06 divisions A-S (excluding classes K633...
# ...       ...                                                ...
# 50980      52  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50981      40  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50982      12  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50983       5  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50984      46  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [50985 rows x 10 columns]

# %% [markdown]
# In Python, we can access the property of an object by accessing it as an attribute.
#
# Hence to access the country property of `data` we can use:

# %%
# DataFrame.<column_name>

data.Year
# Out:
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
#          ...
# 50980    2013
# 50981    2013
# 50982    2013
# 50983    2013
# 50984    2013
# Name: Year, Length: 50985, dtype: int64

# %% [markdown]
# we can access its values using the indexing ([]) operator. We can do the same with columns in a DataFrame:

# %%
# DataFrame['column_name']

data['Year']
# Out:
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
#          ...
# 50980    2013
# 50981    2013
# 50982    2013
# 50983    2013
# 50984    2013
# Name: Year, Length: 50985, dtype: int64

# %% [markdown]
# **Note:** These are two ways of selecting `Series` out of the `DataFrame`. but the indexing operator [ ] does have the advantage that it can handle column names

# %% [markdown]
# Doesn't a pandas Series look kind of like a fancy dictionary? It pretty much is, so it's no surprise that, to drill down to a single specific value, we need only use the indexing operator [ ] once more:

# %%
print(data['Year'][0]) # 2023
print(data['Year'][50984]) # 2013
# Out:
# 2023
# 2013

# %% [markdown]
# ### Indexing in pandas
#
# The indexing operator and attribute selection are nice because they work just like they do in the rest of the Python ecosystem.  However, pandas has its own accessor operators, `loc` and `iloc`. For more advanced operations, these are the ones you're supposed to be using.

# %% [markdown]
# #### Index-based selection
# Pandas indexing works in one of two paradigms. The first is **index-based selection**: selecting data based on its numerical position in the data. iloc follows this paradigm.
#
# To select the first row of data in a DataFrame, we may use the following:

# %%
data.iloc[0]
# Out:
# Year                                                                        2023
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H01
# Variable_name                                                       Total income
# Variable_category                                          Financial performance
# Value                                                                     930995
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 0, dtype: object

# %% [markdown]
# Both `loc` and `iloc` are **row-first, column-second**.
# This is the opposite of what we do in native python, which is **column-first, row-second.**
#
# This means that it's marginally easier to retrieve rows, and marginally harder to get retrieve columns.
# To get a column with `iloc`, we can do the following:

# %%
data.iloc[:,0]
# Out:
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
#          ...
# 50980    2013
# 50981    2013
# 50982    2013
# 50983    2013
# 50984    2013
# Name: Year, Length: 50985, dtype: int64

# %% [markdown]
# ":" operator, which means "everything".
# It can be used to indicate a range of values.
#
# For example to select the `Year` column just the first, second, and third row, we would do:

# %%
data.iloc[:3, 0]
# Out:
# 0    2023
# 1    2023
# 2    2023
# Name: Year, dtype: int64

# %% [markdown]
# Or, to select just the second and third entries, we would do:

# %%
data.iloc[1:3, 0]
# Out:
# 1    2023
# 2    2023
# Name: Year, dtype: int64

# %% [markdown]
# It's also possible to pass a list:

# %%
data.iloc[[0, 1, 3, -1],0]
# Out:
# 0        2023
# 1        2023
# 3        2023
# 50984    2013
# Name: Year, dtype: int64

# %% [markdown]
# This will start counting forward from the `end` of the values.

# %%
data.iloc[-5:]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 50980  Food product manufacturing  Percentage           H37
# 50981  Food product manufacturing  Percentage           H38
# 50982  Food product manufacturing  Percentage           H39
# 50983  Food product manufacturing  Percentage           H40
# 50984  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 50980                          Quick ratio  Financial ratios    52
# 50981  Margin on sales of goods for resale  Financial ratios    40
# 50982                     Return on equity  Financial ratios    12
# 50983               Return on total assets  Financial ratios     5
# 50984                Liabilities structure  Financial ratios    46
#
#                                   Industry_code_ANZSIC06
# 50980  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50981  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50982  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50983  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50984  ANZSIC06 groups C111, C112, C113, C114, C115, ...

# %% [markdown]
# #### Label-based selection
# The second paradigm for attribute selection is the one followed by the loc operator: **label-based selection**. In this paradigm, it's the data index value, not its position, which matters.
#
# For example, to get the first entry in `data`, we would now do the following:

# %%
data.loc[0, 'Year']
# Out:
# 2023

# %% [markdown]
# `iloc` is conceptually simpler then `loc`.
# Because it ignores the datasets indicies.
# When we use `iloc` we treat the dataset like a big matrix (a list of lists), one that we have to index into by position.
#
# `loc` is uses the information in the indicies to do its work.
# Since your dataset usually has meaningful indicies, its usually easier to do things using `loc` instead.

# %%
data.loc[:, ['Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC' , 'Industry_name_NZSIOC']]
# Out:
#       Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0                         Level 1                99999
# 1                         Level 1                99999
# 2                         Level 1                99999
# 3                         Level 1                99999
# 4                         Level 1                99999
# ...                           ...                  ...
# 50980                     Level 3                 ZZ11
# 50981                     Level 3                 ZZ11
# 50982                     Level 3                 ZZ11
# 50983                     Level 3                 ZZ11
# 50984                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC
# 0                  All industries
# 1                  All industries
# 2                  All industries
# 3                  All industries
# 4                  All industries
# ...                           ...
# 50980  Food product manufacturing
# 50981  Food product manufacturing
# 50982  Food product manufacturing
# 50983  Food product manufacturing
# 50984  Food product manufacturing
#
# [50985 rows x 3 columns]

# %% [markdown]
# ### Choosing between `loc`  & `iloc`
#
# `iloc`, uses the python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will entries 0...9
#
# `loc`, indexes inclusively. So 0:10 will entries 0...10

# %% [markdown]
# ## Manipulating the index
# Label-based selection derives its power from the labels in the index. Critically, the index we use is not immutable. We can manipulate the index in any way we see fit.
#
# The `set_index()` method can be used to do the job. Here is what happens when `set_index` to the  `Variable_code`

# %%
data.set_index('Variable_code')
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H01            2023                     Level 1                99999
# H04            2023                     Level 1                99999
# H05            2023                     Level 1                99999
# H07            2023                     Level 1                99999
# H08            2023                     Level 1                99999
# ...             ...                         ...                  ...
# H37            2013                     Level 3                 ZZ11
# H38            2013                     Level 3                 ZZ11
# H39            2013                     Level 3                 ZZ11
# H40            2013                     Level 3                 ZZ11
# H41            2013                     Level 3                 ZZ11
#
#                      Industry_name_NZSIOC               Units  \
# Variable_code
# H01                        All industries  Dollars (millions)
# H04                        All industries  Dollars (millions)
# H05                        All industries  Dollars (millions)
# H07                        All industries  Dollars (millions)
# H08                        All industries  Dollars (millions)
# ...                                   ...                 ...
# H37            Food product manufacturing          Percentage
# H38            Food product manufacturing          Percentage
# H39            Food product manufacturing          Percentage
# H40            Food product manufacturing          Percentage
# H41            Food product manufacturing          Percentage
#
#                                                  Variable_name  \
# Variable_code
# H01                                               Total income
# H04            Sales, government funding, grants and subsidies
# H05                          Interest, dividends and donations
# H07                                       Non-operating income
# H08                                          Total expenditure
# ...                                                        ...
# H37                                                Quick ratio
# H38                        Margin on sales of goods for resale
# H39                                           Return on equity
# H40                                     Return on total assets
# H41                                      Liabilities structure
#
#                    Variable_category   Value  \
# Variable_code
# H01            Financial performance  930995
# H04            Financial performance  821630
# H05            Financial performance   84354
# H07            Financial performance   25010
# H08            Financial performance  832964
# ...                              ...     ...
# H37                 Financial ratios      52
# H38                 Financial ratios      40
# H39                 Financial ratios      12
# H40                 Financial ratios       5
# H41                 Financial ratios      46
#
#                                           Industry_code_ANZSIC06
# Variable_code
# H01            ANZSIC06 divisions A-S (excluding classes K633...
# H04            ANZSIC06 divisions A-S (excluding classes K633...
# H05            ANZSIC06 divisions A-S (excluding classes K633...
# H07            ANZSIC06 divisions A-S (excluding classes K633...
# H08            ANZSIC06 divisions A-S (excluding classes K633...
# ...                                                          ...
# H37            ANZSIC06 groups C111, C112, C113, C114, C115, ...
# H38            ANZSIC06 groups C111, C112, C113, C114, C115, ...
# H39            ANZSIC06 groups C111, C112, C113, C114, C115, ...
# H40            ANZSIC06 groups C111, C112, C113, C114, C115, ...
# H41            ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [50985 rows x 9 columns]

# %% [markdown]
# ## Conditional selection
# This allows you to filter a DataFrame based on certain  conditions.

# %%
data.Year ==  2023 # The Data in the year column was not a string but an integer
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 50980    False
# 50981    False
# 50982    False
# 50983    False
# 50984    False
# Name: Year, Length: 50985, dtype: bool

# %% [markdown]
# This operation produced as `Series` of *True / False* boolens based on the `Year` of each record.
# This result can then be used inside to `loc` to select the relevant data:

# %%
data.loc[data.Year == 2023]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0     2023                     Level 1                99999
# 1     2023                     Level 1                99999
# 2     2023                     Level 1                99999
# 3     2023                     Level 1                99999
# 4     2023                     Level 1                99999
# ...    ...                         ...                  ...
# 4630  2023                     Level 3                 ZZ11
# 4631  2023                     Level 3                 ZZ11
# 4632  2023                     Level 3                 ZZ11
# 4633  2023                     Level 3                 ZZ11
# 4634  2023                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 0                 All industries  Dollars (millions)           H01
# 1                 All industries  Dollars (millions)           H04
# 2                 All industries  Dollars (millions)           H05
# 3                 All industries  Dollars (millions)           H07
# 4                 All industries  Dollars (millions)           H08
# ...                          ...                 ...           ...
# 4630  Food Product Manufacturing          Percentage           H37
# 4631  Food Product Manufacturing          Percentage           H38
# 4632  Food Product Manufacturing          Percentage           H39
# 4633  Food Product Manufacturing          Percentage           H40
# 4634  Food Product Manufacturing          Percentage           H41
#
#                                         Variable_name      Variable_category  \
# 0                                        Total income  Financial performance
# 1     Sales, government funding, grants and subsidies  Financial performance
# 2                   Interest, dividends and donations  Financial performance
# 3                                Non-operating income  Financial performance
# 4                                   Total expenditure  Financial performance
# ...                                               ...                    ...
# 4630                                      Quick ratio       Financial ratios
# 4631              Margin on sales of goods for resale       Financial ratios
# 4632                                 Return on equity       Financial ratios
# 4633                           Return on total assets       Financial ratios
# 4634                            Liabilities structure       Financial ratios
#
#        Value                             Industry_code_ANZSIC06
# 0     930995  ANZSIC06 divisions A-S (excluding classes K633...
# 1     821630  ANZSIC06 divisions A-S (excluding classes K633...
# 2      84354  ANZSIC06 divisions A-S (excluding classes K633...
# 3      25010  ANZSIC06 divisions A-S (excluding classes K633...
# 4     832964  ANZSIC06 divisions A-S (excluding classes K633...
# ...      ...                                                ...
# 4630      89  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 4631      38  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 4632      17  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 4633       8  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 4634      48  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [4635 rows x 10 columns]

# %% [markdown]
# The DataFrame has 635 rows. The origial was ~50K.
# We wanted to know which `Value` has value of  `C`
# We can use the ampersan (&) to bring the two questions together:

# %%
data.loc[(data.Year == 2023) & (data.Value == 'C')]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 747   2023                     Level 3                 CC32
# 751   2023                     Level 3                 CC32
# 771   2023                     Level 3                 CC32
# 772   2023                     Level 3                 CC32
# 776   2023                     Level 3                 CC32
# ...    ...                         ...                  ...
# 4466  2023                     Level 4                RS113
# 4467  2023                     Level 4                RS113
# 4602  2023                     Level 3                 ZZ11
# 4603  2023                     Level 3                 ZZ11
# 4610  2023                     Level 3                 ZZ11
#
#                                    Industry_name_NZSIOC               Units  \
# 747   Pulp, Paper and Converted Paper Product Manufa...  Dollars (millions)
# 751   Pulp, Paper and Converted Paper Product Manufa...  Dollars (millions)
# 771   Pulp, Paper and Converted Paper Product Manufa...  Dollars (millions)
# 772   Pulp, Paper and Converted Paper Product Manufa...  Dollars (millions)
# 776   Pulp, Paper and Converted Paper Product Manufa...          Percentage
# ...                                                 ...                 ...
# 4466                                Gambling Activities          Percentage
# 4467                                Gambling Activities          Percentage
# 4602                         Food Product Manufacturing  Dollars (millions)
# 4603                         Food Product Manufacturing  Dollars (millions)
# 4610                         Food Product Manufacturing  Dollars (millions)
#
#      Variable_code                             Variable_name  \
# 747            H02      Sales of goods not further processed
# 751            H07                      Non-operating income
# 771            H31       Shareholders funds or owners equity
# 772            H32                       Current liabilities
# 776            H36                             Current ratio
# ...            ...                                       ...
# 4466           H36                             Current ratio
# 4467           H37                               Quick ratio
# 4602           H05         Interest, dividends and donations
# 4603           H06  Government funding, grants and subsidies
# 4610           H13                  Redundancy and severance
#
#           Variable_category Value  \
# 747   Financial performance     C
# 751   Financial performance     C
# 771      Financial position     C
# 772      Financial position     C
# 776        Financial ratios     C
# ...                     ...   ...
# 4466       Financial ratios     C
# 4467       Financial ratios     C
# 4602  Financial performance     C
# 4603  Financial performance     C
# 4610  Financial performance     C
#
#                                  Industry_code_ANZSIC06
# 747                       ANZSIC06 groups C151 and C152
# 751                       ANZSIC06 groups C151 and C152
# 771                       ANZSIC06 groups C151 and C152
# 772                       ANZSIC06 groups C151 and C152
# 776                       ANZSIC06 groups C151 and C152
# ...                                                 ...
# 4466                                ANZSIC06 group R920
# 4467                                ANZSIC06 group R920
# 4602  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 4603  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 4610  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [176 rows x 10 columns]

# %% [markdown]
# #### Pandas comes with a few build-in conditional selectors.
# 1. `isin` is lets you select data whose value "is in" a list of values.

# %%
data.loc[data.Year.isin([2023,2022])]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0     2023                     Level 1                99999
# 1     2023                     Level 1                99999
# 2     2023                     Level 1                99999
# 3     2023                     Level 1                99999
# 4     2023                     Level 1                99999
# ...    ...                         ...                  ...
# 9265  2022                     Level 3                 ZZ11
# 9266  2022                     Level 3                 ZZ11
# 9267  2022                     Level 3                 ZZ11
# 9268  2022                     Level 3                 ZZ11
# 9269  2022                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 0                 All industries  Dollars (millions)           H01
# 1                 All industries  Dollars (millions)           H04
# 2                 All industries  Dollars (millions)           H05
# 3                 All industries  Dollars (millions)           H07
# 4                 All industries  Dollars (millions)           H08
# ...                          ...                 ...           ...
# 9265  Food Product Manufacturing          Percentage           H37
# 9266  Food Product Manufacturing          Percentage           H38
# 9267  Food Product Manufacturing          Percentage           H39
# 9268  Food Product Manufacturing          Percentage           H40
# 9269  Food Product Manufacturing          Percentage           H41
#
#                                         Variable_name      Variable_category  \
# 0                                        Total income  Financial performance
# 1     Sales, government funding, grants and subsidies  Financial performance
# 2                   Interest, dividends and donations  Financial performance
# 3                                Non-operating income  Financial performance
# 4                                   Total expenditure  Financial performance
# ...                                               ...                    ...
# 9265                                      Quick ratio       Financial ratios
# 9266              Margin on sales of goods for resale       Financial ratios
# 9267                                 Return on equity       Financial ratios
# 9268                           Return on total assets       Financial ratios
# 9269                            Liabilities structure       Financial ratios
#
#        Value                             Industry_code_ANZSIC06
# 0     930995  ANZSIC06 divisions A-S (excluding classes K633...
# 1     821630  ANZSIC06 divisions A-S (excluding classes K633...
# 2      84354  ANZSIC06 divisions A-S (excluding classes K633...
# 3      25010  ANZSIC06 divisions A-S (excluding classes K633...
# 4     832964  ANZSIC06 divisions A-S (excluding classes K633...
# ...      ...                                                ...
# 9265      82  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 9266      30  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 9267      12  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 9268       5  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 9269      45  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [9270 rows x 10 columns]

# %% [markdown]
# 2. `isnull (and its comparison not null). These method let you highlight value which are (or are not) empty (NaN)

# %%
data.loc[data.Variable_code.notnull()]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# 3                  All industries  Dollars (millions)           H07
# 4                  All industries  Dollars (millions)           H08
# ...                           ...                 ...           ...
# 50980  Food product manufacturing          Percentage           H37
# 50981  Food product manufacturing          Percentage           H38
# 50982  Food product manufacturing          Percentage           H39
# 50983  Food product manufacturing          Percentage           H40
# 50984  Food product manufacturing          Percentage           H41
#
#                                          Variable_name      Variable_category  \
# 0                                         Total income  Financial performance
# 1      Sales, government funding, grants and subsidies  Financial performance
# 2                    Interest, dividends and donations  Financial performance
# 3                                 Non-operating income  Financial performance
# 4                                    Total expenditure  Financial performance
# ...                                                ...                    ...
# 50980                                      Quick ratio       Financial ratios
# 50981              Margin on sales of goods for resale       Financial ratios
# 50982                                 Return on equity       Financial ratios
# 50983                           Return on total assets       Financial ratios
# 50984                            Liabilities structure       Financial ratios
#
#         Value                             Industry_code_ANZSIC06
# 0      930995  ANZSIC06 divisions A-S (excluding classes K633...
# 1      821630  ANZSIC06 divisions A-S (excluding classes K633...
# 2       84354  ANZSIC06 divisions A-S (excluding classes K633...
# 3       25010  ANZSIC06 divisions A-S (excluding classes K633...
# 4      832964  ANZSIC06 divisions A-S (excluding classes K633...
# ...       ...                                                ...
# 50980      52  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50981      40  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50982      12  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50983       5  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50984      46  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [50985 rows x 10 columns]

# %% [markdown]
# ### Assigning data
# You can assign either a contact value:

# %%
data['Year'] = 2023
data['Year']
# Out:
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
#          ...
# 50980    2023
# 50981    2023
# 50982    2023
# 50983    2023
# 50984    2023
# Name: Year, Length: 50985, dtype: int64

# %% [markdown]
# Or with an iterable of values:

# %%
data['Year',] = range(len(data), 0, -1)
print(data['Year'])
# Out:
# 0        50985
# 1        50984
# 2        50983
# 3        50982
# 4        50981
#          ...
# 50980        5
# 50981        4
# 50982        3
# 50983        2
# 50984        1
# Name: Year, Length: 50985, dtype: int64
